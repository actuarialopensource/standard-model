# %%
import modelx as mx
import timeit

# %%
model = mx.read_model("TermParallel.zip")

# %%
timeit.timeit('model.Projection.monthly_risk_premium()', number=1, globals=globals())
# Out:
# 1.5706783

# %%
model.Projection.monthly_risk_premium()
# Out:
# array([136.65,  52.74,  93.32,  75.98,  29.3 ,  60.46, 103.59,  19.82,
#         58.63,  62.77,  35.97, 161.13,  19.66,  10.15,  93.36,  63.63,
#         33.2 ,  24.3 ,  11.81,  66.15, 123.4 , 203.29,  42.51, 144.23,
#         85.48,  33.75,  24.58,  15.53,  44.61,  45.49,  75.11,  54.9 ,
#         62.93, 522.21,  11.07,  25.13,   9.94,  14.32,  45.06,  67.3 ,
#         28.25,  23.21, 313.29,  51.93,  81.02, 209.74,  18.15,  17.2 ,
#         55.15,   8.71,  56.63, 102.28,  23.51,  53.76,  54.45,  12.99,
#         23.07,  34.37,  10.84,  36.54,  60.87,  51.46, 138.7 ,  83.69,
#          8.71, 125.32,  34.69,  48.42,  27.25, 159.64,  58.89,  26.63,
#         17.14,  56.62,  48.4 , 219.1 ,  15.18,  70.05,  17.35,  11.55,
#        112.33, 211.08,  19.56, 175.65,  30.93,  12.01,  20.8 ,  37.69,
#         20.78,  57.76, 167.48,  54.19,  54.52, 194.75,  26.05,  92.35,
#         26.08,  12.64, 144.37, 153.26,  14.4 ,  37.89,  43.95,  27.95,
# ...

# %%
model_10k = mx.read_model("TermParallel10k.zip")

# %%
timeit.timeit('model_10k.Projection.monthly_risk_premium()', number=1, globals=globals())
# Out:
# 2.5535796

# %%
model_10k.Projection.monthly_risk_premium()
# Out:
# array([136.65,  52.74,  93.32, ...,  31.04, 152.98, 381.67])
